# %%
import pandas as pd
df = pd.read_csv ('donner_party1.csv')
df
# Out:
#     Survived                        Name Sex   Age Marital Status
# 0          1               Patrick Breen   M  51.0              M
# 1          1              Margaret Breen   F  40.0              M
# 2          1                  John Breen   M  14.0              S
# 3          1           Patrick Breen Jr.   M   9.0              S
# 4          1         Simon Preston Breen   M   8.0              S
# 5          1       James Frederick Breen   M   5.0              S
# 6          1                 Peter Breen   M   3.0              S
# 7          1              Isabella Breen   F   1.0              S
# 8          1          James Frazier Reed   M  45.0              M
# 9          1         Margaret Keyes Reed   F  32.0              M
# 10         1     Virginia BackenstoeReed   F  13.0              S
# 11         1            Martha Jane Reed   F   8.0              S
# 12         1           James F. Reed Jr.   M   5.0              S
# ...

# %%
numOfRows = df.shape[0]
 
print('Members in the Donner Party: ' , numOfRows)
# Out:
# Members in the Donner Party:  89

# %%
survive= pd.Series(['Survived'])
survive.sum
#Not quite working. Need to mess with the data set, remove the index, sum up survivers, compare survivor rate of gender and age
# Out:
# <bound method Series.sum of 0    Survived
# dtype: object>
